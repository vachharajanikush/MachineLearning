# %%
#Data visualization
#line chart, bar chart, histogram, scatterplot
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/Admin/Desktop/Placement_Data_Full_Class.csv')
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
df.plot()
plt.show()

# %%
#Scatter Plot
df.plot(kind='scatter', x='ssc_p',y='hsc_p',color='blue')
plt.title('Scatter Graph')
#plt.show()
# Out:
# Text(0.5, 1.0, 'Scatter Graph')

# %%
df1=df.head(2)
ax=plt.gca()
plt.title('Scatter Graph')
df.plot(kind='scatter', x='ssc_p',y='hsc_p',color='red',ax=ax)

# plt.gca is get current axes
# Out:
# <AxesSubplot:title={'center':'Scatter Graph'}, xlabel='ssc_p', ylabel='hsc_p'>

# %%
#Bar Graph
df1.plot(kind='bar',x='ssc_p',y='hsc_p',color='orange')
plt.title('Bar Graph')
plt.show()

# %%
#Line Chart
df1.plot(kind='line',x='ssc_p',y='hsc_p',color='green')
plt.title('Line Graph')
plt.show()

# %%
ax=plt.gca()
df1.plot(kind='line',x='ssc_p',color='red',ax=ax)
df1.plot(kind='line',x='ssc_p',color='red',ax=ax)
df1.plot(kind='line',x='ssc_p',y='hsc_p',color='yellow',ax=ax)
plt.show()

#aana thi ekj window ma 3 graph generate thay matlab jetla leva hoy lai shakie

# %%
#Creating DataFrame and Loading csv file
df = pd.read_csv('iris.csv')
df

# Data Visualization - Histogram
#1. Histogram for Iris Dataset

x = df["SepalLengthCm"]
plt.hist(x, bins = 20, color = "blue")
plt.title("Sepal Length in cm")
plt.xlabel("Sepal_Length_cm")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# Data Visualization - Boxplot
#2. Boxplot for Iris Dataset

df1 = df[["SepalLengthCm",'SepalWidthCm','PetalLengthCm','PetalWidthCm']]
print(df1.describe())
df1.boxplot()

#IQR = Q3-Q1
#Outliers are the data points below and above the lower and upper limit.
# The lower and upper limit is calculated as – 

#Lower Limit = Q1 - 1.5*IQR
#Upper Limit = Q3 + 1.5*IQR
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000
# <AxesSubplot:>

# %%
# easy methods che ama.. ama khali lineplot generate nai thay 
x = df["SepalLengthCm"]
y = df["SepalWidthCm"]

#plt.scatter(x,y, color = "blue")
#plt.boxplot(x)
#plt.hist(x)
plt.bar(x,y)
# Out:
# <BarContainer object of 150 artists>

# %%
df2=df[["SepalLengthCm",'SepalWidthCm','PetalLengthCm','PetalWidthCm']]
df2.plot(kind='bar',x='SepalLengthCm',y='SepalWidthCm',color='green')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm'>

# %%
df2.lineplot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11776\4078045923.py in <module>
# ----> 1 df2.lineplot()
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'lineplot'
